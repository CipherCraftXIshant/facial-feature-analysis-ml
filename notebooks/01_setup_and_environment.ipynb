# %% [markdown]
# # Notebook 01: Setup and Environment
#
# ## Purpose
# This notebook verifies the Python environment setup, imports core libraries required for the facial feature analysis project, provides instructions for downloading the UTKFace dataset via the Kaggle API, and prints library version information to confirm the environment works.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# Instructions for uploading kaggle.json and downloading dataset:
# 1. Upload your kaggle.json file (obtained from Kaggle Account Settings -> Create New API Token).
# 2. Place kaggle.json in standard location (~/.kaggle/kaggle.json) or current working directory.
# 3. Run the following command to download and unzip UTKFace dataset to data/raw/:
#
# kaggle datasets download -d jangedoo/utkface-new -p data/raw/ --unzip

# %%
import numpy
import pandas
import sklearn

print(f"NumPy version: {numpy.__version__}")
print(f"Pandas version: {pandas.__version__}")
print(f"scikit-learn version: {sklearn.__version__}")
